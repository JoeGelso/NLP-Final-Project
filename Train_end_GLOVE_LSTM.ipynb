# %% [markdown]
# In this notebook, we experiment with a binary classification for the ending sentence for stories using our text classification model we developed in HW4, this time with the pretrained GLOVE embeddings, and an LSTM, with possibility of bidirectional capabilities

# %%
#imports
import pandas as pd
from collections import Counter, defaultdict
import torch
import torch.utils.data
import numpy as np
import string
from nltk import word_tokenize
from sklearn.metrics import accuracy_score

print("Cuda available:", torch.cuda.is_available())
# Out:
# Cuda available: True

# %%
#load the datasets
data_train_raw = pd.read_csv("ROCStories_winter2017.csv")
data_test_raw = pd.read_csv("cloze_test_2016.csv")
data_val_raw = pd.read_csv("cloze_val_2016.csv")


#test set 
endings = data_test_raw.RandomFifthSentenceQuiz1.tolist(),data_test_raw.RandomFifthSentenceQuiz2.tolist()
answers =data_test_raw.AnswerRightEnding.tolist()
#seperate the endings for each example into appropriate lists
test_true = []
test_false = []
num_instances , num_columns = data_test_raw.shape
for i in range(num_instances):
    test_true.append(endings[answers[i]-1][i])
    test_false.append(endings[(answers[i]+2)%2][i])
    

# validation set (duplicate code from above, probably couldve just made a function to process the test and
# val sets but oh well)
val_endings = data_val_raw.RandomFifthSentenceQuiz1.tolist(),data_val_raw.RandomFifthSentenceQuiz2.tolist()
val_answers =data_val_raw.AnswerRightEnding.tolist()
#seperate the endings for each example into appropriate lists
val_true = []
val_false = []
num_instances , num_columns = data_val_raw.shape
for i in range(num_instances):
    val_true.append(val_endings[val_answers[i]-1][i])
    val_false.append(val_endings[(val_answers[i]+2)%2][i])
    
#check the first 20 examples in the test and val set to see how it looks
print("**********TEST SET**********\n")
for i in range(200):
    print("TRUE ENDING:\t", test_true[i])
    print("FALSE ENDING:\t", test_false[i])
    print("\n")
    
print("**********VALIDATION SET**********\n")
for i in range(200):
    print("TRUE ENDING:\t", val_true[i])
    print("FALSE ENDING:\t", val_false[i])
    print("\n")
    
#lets create a list of tuples for each of these sets
test_set = []
val_set = []
#test set
for i in range(len(test_true)):
    test_set.append((test_true[i], 'Coherent'))
for i in range(len(test_false)):
    test_set.append((test_false[i], 'Incoherent'))
#val set
for i in range(len(val_true)):
    val_set.append((val_true[i], 'Coherent'))
for i in range(len(val_false)):
    val_set.append((val_false[i], 'Incoherent'))
# Out:
# **********TEST SET**********
#
# TRUE ENDING:	 The next weekend, I was asked to please stay home.
# FALSE ENDING:	 My friends decided to keep inviting me out as I am so much fun.
#
#
# TRUE ENDING:	 My allergies were too bad and I had to go back home.
# FALSE ENDING:	 It reminded me of how much I loved spring flowers.
#
#
# TRUE ENDING:	 Avery regretted what she did the next day.
# FALSE ENDING:	 Avery thought her children would be happy with her decision.
#
#
# TRUE ENDING:	 Josh got sick.
# FALSE ENDING:	 Josh thought that the pie was delicious.
#
#
# TRUE ENDING:	 He felt inspiration and then went back home to write.
# FALSE ENDING:	 John then got an idea for his painting.
#
#
# TRUE ENDING:	 The cashier handed them the cash so they would go away.
# FALSE ENDING:	 The cashier invited the men to her high school reunion.
#
#
# TRUE ENDING:	 They called the police to come to my house.
# FALSE ENDING:	 They liked me a lot after that.
#
#
# TRUE ENDING:	 Kerry was so grateful!
# FALSE ENDING:	 Kerry was disappointed.
#
#
# TRUE ENDING:	 Franny learned to examine her prejudices.
# FALSE ENDING:	 Franny ended up getting deported.
#
#
# TRUE ENDING:	 Luckily he had been saving everything on an external disk.
# FALSE ENDING:	 When he finished his paper he went to bed.
#
#
# TRUE ENDING:	 Ari opens the jar to find perfect pickles.
# FALSE ENDING:	 Ari's pickles are sweet.
#
#
# TRUE ENDING:	 Trudey hoped self-publishing would be more profitable.
# FALSE ENDING:	 Trudey called her sister and asked her to come to dinner.
#
#
# TRUE ENDING:	 Feliciano was happy about his nice day.
# FALSE ENDING:	 The pair then went out to pick olives.
#
#
# TRUE ENDING:	 Aaron suggested he help her cook another meal instead.
# FALSE ENDING:	 Aaron broke up with her.
#
#
# TRUE ENDING:	 Oliver was so grateful for his wife's love.
# FALSE ENDING:	 Oliver decided to not get married.
#
#
# TRUE ENDING:	 Somebody found her cat.
# FALSE ENDING:	 Sarah broke her leg.
#
#
# TRUE ENDING:	 Kelly was so happy to finally beat it.
# FALSE ENDING:	 Kelly was mad about that.
#
#
# TRUE ENDING:	 Deb said yes to Tim's marriage proposal.
# FALSE ENDING:	 Deb told Tim she was only interested in woman.
#
#
# TRUE ENDING:	 I loved them anyway.
# FALSE ENDING:	 I thought the cereal was delicious.
#
#
# TRUE ENDING:	 I have very fond memories of checkers.
# FALSE ENDING:	 To this day I hate checkers.
#
#
# TRUE ENDING:	 She loved her new phone.
# FALSE ENDING:	 Amy spent all of her money on clothes.
#
#
# TRUE ENDING:	 They were on sale.
# FALSE ENDING:	 Dave bought an entire case.
#
#
# TRUE ENDING:	 Gina decided to go outside and pick some of the weeds.
# FALSE ENDING:	 Gina asked her grandpa what kind of flowers he liked best.
#
#
# TRUE ENDING:	 She was offered the new job at a higher salary.
# FALSE ENDING:	 Ramona had no reason to want to change jobs.
#
#
# TRUE ENDING:	 My parents gave me enough money to buy the console.
# FALSE ENDING:	 At the end of the summer I gave the money back to my parents.
#
#
# TRUE ENDING:	 Felipe visited Germany again later in his life.
# FALSE ENDING:	 Felipe never wanted to go to Germany again.
#
#
# TRUE ENDING:	 Miles decided that he needed to be more careful.
# FALSE ENDING:	 Miles got up and walked away.
#
#
# TRUE ENDING:	 Johnny did not ask Anita out again.
# FALSE ENDING:	 Johnny wanted to ask Anita out again.
#
#
# TRUE ENDING:	 He was near death for sure, he would be gone before night's end.
# FALSE ENDING:	 He got up and decided to go for a jog.
#
#
# TRUE ENDING:	 Tom hurried to study as much as possible before the test.
# FALSE ENDING:	 Tom felt prepared for the test.
#
#
# TRUE ENDING:	 He decided to buy more lunch and then he felt sick.
# FALSE ENDING:	 He then stopped eating because he was full.
#
#
# TRUE ENDING:	 Jill and her dad took both kittens home.
# FALSE ENDING:	 Jill and her dad took one kitten home.
#
#
# TRUE ENDING:	 I got a nice sun tan that day.
# FALSE ENDING:	 I was hit in the face with a football and got a black eye.
#
#
# TRUE ENDING:	 The dog ran home with his tail between his legs.
# FALSE ENDING:	 The other dog got the better of him and bit his ear.
#
#
# TRUE ENDING:	 Peter's daughter enjoyed the music.
# FALSE ENDING:	 Peter hated Christmas.
#
#
# TRUE ENDING:	 Yao placed in two categories.
# FALSE ENDING:	 The judges ate Yao's vegetables without rewarding him.
#
#
# TRUE ENDING:	 Mary was glad she learned to jump rope.
# FALSE ENDING:	 Mary lost her job because she didn't have any stamina.
#
#
# TRUE ENDING:	 He filled my order.
# FALSE ENDING:	 He told me to go to hell.
#
#
# TRUE ENDING:	 His friend loved the tacos that Scott cooked.
# FALSE ENDING:	 His friend was so offended he asked Scott to leave.
#
#
# TRUE ENDING:	 He was asked to join the team.
# FALSE ENDING:	 He played terribly.
#
#
# TRUE ENDING:	 Beth had just won the lottery!
# FALSE ENDING:	 Beth's dog had been hit by a car!
#
#
# TRUE ENDING:	 The water exploded.
# FALSE ENDING:	 The water was very still.
#
#
# TRUE ENDING:	 Her best friend was elated.
# FALSE ENDING:	 Her best friend felt angry.
#
#
# TRUE ENDING:	 Gordon vows to be more careful next time.
# FALSE ENDING:	 Gordon is fired for being late to the meeting.
#
#
# TRUE ENDING:	 The police had to come to break up the argument.
# FALSE ENDING:	 They complemented each other on how tasty the cake was.
#
#
# TRUE ENDING:	 Mike was sad to see his girlfriend with someone else.
# FALSE ENDING:	 Mike was glad he didn't walk around the schoolyard.
#
#
# TRUE ENDING:	 Kara asked the neighbors not to put out dog treats in their yard.
# FALSE ENDING:	 Kara bought a pet cat and dyed it pink.
#
#
# TRUE ENDING:	 After saving her, we were all relieved.
# FALSE ENDING:	 We then let her go swimming.
#
#
# TRUE ENDING:	 The harpooner went down with the ship.
# FALSE ENDING:	 The harpooner emerged on a surfboard.
#
#
# TRUE ENDING:	 Sarah was so depressed.
# FALSE ENDING:	 Sarah was delighted she dropped the toast.
#
#
# TRUE ENDING:	 After that, we went home and peacefully slept.
# FALSE ENDING:	 We then left six flags and went home.
#
#
# TRUE ENDING:	 She thought she could be an honorary aunt.
# FALSE ENDING:	 She decided she didn't like babies.
#
#
# TRUE ENDING:	 A big wave knocked Mary down.
# FALSE ENDING:	 The ocean was a calm as a bathtub.
#
#
# TRUE ENDING:	 Ashley got a part time job too.
# FALSE ENDING:	 Jeff quit his job that day.
#
#
# TRUE ENDING:	 Josh loved the outdoors.
# FALSE ENDING:	 Josh loathed the outdoors.
#
#
# TRUE ENDING:	 We had court side seats.
# FALSE ENDING:	 We decided to leave after sitting down.
#
#
# TRUE ENDING:	 It was just what she wanted.
# FALSE ENDING:	 She was very allergic to poison ivy.
#
#
# TRUE ENDING:	 I know I'll get there one day.
# FALSE ENDING:	 I know I'll eat pears one day.
#
#
# TRUE ENDING:	 She had a wonderful time.
# FALSE ENDING:	 She was disappointed.
#
#
# TRUE ENDING:	 He thanked his parents for taking him to a movie.
# FALSE ENDING:	 He cried incessantly and begged to go home.
#
#
# TRUE ENDING:	 He couldn't find the tuna.
# FALSE ENDING:	 He didn't look for the tuna.
#
#
# TRUE ENDING:	 To his relief she accepted.
# FALSE ENDING:	 She had been away on a trip in Alaska for some time.
#
#
# TRUE ENDING:	 Lira never listened to the rappers music again.
# FALSE ENDING:	 Lira became one of the rapper's roadies.
#
#
# TRUE ENDING:	 Caitlin felt guilty and came clean to her mom.
# FALSE ENDING:	 Caitlin's sister took the punishment justly.
#
#
# TRUE ENDING:	 Andrea introduced the dog to the family.
# FALSE ENDING:	 Andrea gave the dog to a stranger.
#
#
# TRUE ENDING:	 They got married eight months later.
# FALSE ENDING:	 Will was very upset that Anna said yes.
#
#
# TRUE ENDING:	 Each time she rode a different animal making her happy.
# FALSE ENDING:	 Ellie cried both times because she didn't want to ride the ride.
#
#
# TRUE ENDING:	 My friends stopped playing to help me off the field.
# FALSE ENDING:	 I got back up to finish the game.
#
#
# TRUE ENDING:	 My rehab therapist is motivational.
# FALSE ENDING:	 My rehab therapist is a narcissist.
#
#
# TRUE ENDING:	 I took them back to the store and got a different size.
# FALSE ENDING:	 My girlfriend just completed a degree in Soil Management.
#
#
# TRUE ENDING:	 A stranger had found her purse and returned it to the restaurant.
# FALSE ENDING:	 A stranger had stolen her purse.
#
#
# TRUE ENDING:	 A year later he was promoted again.
# FALSE ENDING:	 Pete quit his job, and never looked back.
#
#
# TRUE ENDING:	 I was really happy to see her and we made plans.
# FALSE ENDING:	 I was not happy to hear from her so we broke up.
#
#
# TRUE ENDING:	 She tried to be as quiet as possible while she sobbed.
# FALSE ENDING:	 She couldn't help but burst into peals of laughter.
#
#
# TRUE ENDING:	 Gina had a great time.
# FALSE ENDING:	 Gina was sad.
#
#
# TRUE ENDING:	 Agatha decided to return them.
# FALSE ENDING:	 Agatha decided to buy two more.
#
#
# TRUE ENDING:	 Their parents said yes, and they went to the movies.
# FALSE ENDING:	 Their parents said they had to complete their chores first.
#
#
# TRUE ENDING:	 He did a great job.
# FALSE ENDING:	 He told me to cut it myself.
#
#
# TRUE ENDING:	 So she got cozy with the agent.
# FALSE ENDING:	 Sandra told the agent to leave her alone.
#
#
# TRUE ENDING:	 She then brought out a cake and they all felt better.
# FALSE ENDING:	 She told them that she did not have the cake.
#
#
# TRUE ENDING:	 Before long Sarah began getting better at Algebra.
# FALSE ENDING:	 Then Sarah gave up on learning Algebra.
#
#
# TRUE ENDING:	 He built his very own tractor.
# FALSE ENDING:	 Lewy decided to throw all the worthless tractor parts away.
#
#
# TRUE ENDING:	 Bill was the proudest.
# FALSE ENDING:	 Bill is ashamed.
#
#
# TRUE ENDING:	 Dan was able to find an owner for the dog.
# FALSE ENDING:	 Dan gave up and released the dog back into the wild.
#
#
# TRUE ENDING:	 A passer-by helped her up and helped her collect the papers.
# FALSE ENDING:	 The teacher got up and walked home leaving the papers behind.
#
#
# TRUE ENDING:	 The Bradleys then had a great camping trip.
# FALSE ENDING:	 The Bradleys turned around and drove home.
#
#
# TRUE ENDING:	 Don and his wife got the movie.
# FALSE ENDING:	 Don and his wife gave up and went home.
#
#
# TRUE ENDING:	 After much wasted money, the tattoo was gone.
# FALSE ENDING:	 Missy got another tattoo on her cheek.
#
#
# TRUE ENDING:	 Jon was happy to see his weight loss results.
# FALSE ENDING:	 John had a burger and fries for dinner.
#
#
# TRUE ENDING:	 The home team's stands were full when the game began.
# FALSE ENDING:	 No one in town cared to attend the game.
#
#
# TRUE ENDING:	 All of his roommates made coffee.
# FALSE ENDING:	 All of his roommates were sick of coffee.
#
#
# TRUE ENDING:	 Maggie and her dog are best friends.
# FALSE ENDING:	 Maggie hates to spend time with her smelly dog.
#
#
# TRUE ENDING:	 Ella realized it really didn't matter what dress she chose.
# FALSE ENDING:	 Ella was mad because her boyfriend was so critical.
#
#
# TRUE ENDING:	 Ben never starts working out.
# FALSE ENDING:	 Ben goes to the gym every day.
#
#
# TRUE ENDING:	 Our daughter was very thankful for the gift.
# FALSE ENDING:	 Our daughter felt depressed.
#
#
# TRUE ENDING:	 Chris then opened a business and became successful.
# FALSE ENDING:	 Chris could not sell any eggs.
#
#
# TRUE ENDING:	 After listening, the kids then made wonderful art.
# FALSE ENDING:	 The kids then began to write their own songs.
#
#
# TRUE ENDING:	 Mom will never shop at that store at night again.
# FALSE ENDING:	 Mom slapped Chief Brody for not closing the  beaches.
#
#
# TRUE ENDING:	 Finally Sal got to the next level with the help of his cousin.
# FALSE ENDING:	 They spent the afternoon reading books together.
#
#
# TRUE ENDING:	 After he quit, he managed to find a better job.
# FALSE ENDING:	 Will was then fired from his job.
#
#
# TRUE ENDING:	 Bob was nervous about what the cleaners would think of him.
# FALSE ENDING:	 Bob proudly showed his house to the cleaners.
#
#
# TRUE ENDING:	 It was a spectacular and memorable night.
# FALSE ENDING:	 My girlfriend did not want to go on anymore dates with me.
#
#
# TRUE ENDING:	 I gave in and accepted the food since I was hungry.
# FALSE ENDING:	 I did not find the food tempting at all.
#
#
# TRUE ENDING:	 She asked the shelter worker about adopting the dog.
# FALSE ENDING:	 She swatted the dog with a newspaper.
#
#
# TRUE ENDING:	 Rufus had determination.
# FALSE ENDING:	 Rufus was not very musical.
#
#
# TRUE ENDING:	 The story quickly replaced his stereo.
# FALSE ENDING:	 The stereo was perfectly fine.
#
#
# TRUE ENDING:	 Fortunately, her son was too young to remember her mistake.
# FALSE ENDING:	 She was very proud of herself.
#
#
# TRUE ENDING:	 Kate won one hundred dollars.
# FALSE ENDING:	 Kate did not sell any doughnuts.
#
#
# TRUE ENDING:	 His family loved it.
# FALSE ENDING:	 It was the best apple juice that they had ever had.
#
#
# TRUE ENDING:	 Lily enjoyed writing the book.
# FALSE ENDING:	 Lily hated writing.
#
#
# TRUE ENDING:	 Drew made a mess.
# FALSE ENDING:	 Drew kept his car clean this way.
#
#
# TRUE ENDING:	 The phone broke.
# FALSE ENDING:	 Sally was happy.
#
#
# TRUE ENDING:	 The engine roared and off Gordon went.
# FALSE ENDING:	 Gordon thought overgrown grass was rustic and appealing.
#
#
# TRUE ENDING:	 So, Mary decided to walk to work rather than wait for the bus.
# FALSE ENDING:	 So, Mary decided to go get a coffee rather than wait for the bus.
#
#
# TRUE ENDING:	 I made the painting and felt proud.
# FALSE ENDING:	 I could not come up with any ideas.
#
#
# TRUE ENDING:	 Dawn felt happy about getting away with it.
# FALSE ENDING:	 Cora then confronted Dawn about doing it.
#
#
# TRUE ENDING:	 Sam liked it.
# FALSE ENDING:	 Sam hated it.
#
#
# TRUE ENDING:	 A year later they were married.
# FALSE ENDING:	 Alma wished she had never gone to that restaurant.
#
#
# TRUE ENDING:	 Tim is happy to go to the coffee shop every day .
# FALSE ENDING:	 Tim opens his own coffee shop across the street.
#
#
# TRUE ENDING:	 The wine tasted delicious, which made me very happy.
# FALSE ENDING:	 The cake still wasn't prepared correctly.
#
#
# TRUE ENDING:	 They find out the house has already been sold.
# FALSE ENDING:	 They buy a yacht.
#
#
# TRUE ENDING:	 Afraid of germs, Kate and Greg threw the candy in the trash.
# FALSE ENDING:	 Kate and Greg licked the candy gleefully.
#
#
# TRUE ENDING:	 Larry learned a lot about copyright from his experience.
# FALSE ENDING:	 Larry enjoyed the interaction he received from those artists.
#
#
# TRUE ENDING:	 They had more fun at the resort than they would have at the park.
# FALSE ENDING:	 They decided to never return to the resort.
#
#
# TRUE ENDING:	 We had a great time together.
# FALSE ENDING:	 I slammed down a glass and stormed out of the restaurant.
#
#
# TRUE ENDING:	 I'll never buy Proactiv again.
# FALSE ENDING:	 I thoroughly enjoyed the experience.
#
#
# TRUE ENDING:	 They said yes!
# FALSE ENDING:	 Amy hated her family.
#
#
# TRUE ENDING:	 So Shannon decided to look for her necklace at home.
# FALSE ENDING:	 Shannon bought a dog to replace it.
#
#
# TRUE ENDING:	 Sandy could now see in her home.
# FALSE ENDING:	 Sandy still could not see in her home!
#
#
# TRUE ENDING:	 So she borrowed the money from a friend.
# FALSE ENDING:	 Her parents stole her key.
#
#
# TRUE ENDING:	 Hank was disappointed there weren't any white cars left in stock.
# FALSE ENDING:	 Hank bought a black car.
#
#
# TRUE ENDING:	 I think she'll be surprised and delighted by all of it.
# FALSE ENDING:	 It's bound to be the best Christmas ever.
#
#
# TRUE ENDING:	 Clayton is very happy with his new car.
# FALSE ENDING:	 Clayton gives his car away.
#
#
# TRUE ENDING:	 Now Horatio enjoys traveling to many big cities.
# FALSE ENDING:	 Horatio will never travel to a big city again.
#
#
# TRUE ENDING:	 He jumped, startled and ran for his house.
# FALSE ENDING:	 He jumped up and several of the bees stung him.
#
#
# TRUE ENDING:	 His dad's teasing makes Henry feel bad.
# FALSE ENDING:	 Henry wished he looked like the handsome mailman.
#
#
# TRUE ENDING:	 Samantha likes the color of her car now.
# FALSE ENDING:	 Samantha thinks her bus looks pretty now.
#
#
# TRUE ENDING:	 Alex started a home business as one extra credit assignment.
# FALSE ENDING:	 Alex skipped his Economics class because it was so hard.
#
#
# TRUE ENDING:	 Ivan apologized and turned the oven off.
# FALSE ENDING:	 They were all pleased that Ivan had turned on the oven.
#
#
# TRUE ENDING:	 The worker recommended a few different computers to Molly.
# FALSE ENDING:	 The worker told Molly to keep using the computer she had at home.
#
#
# TRUE ENDING:	 He was scolded.
# FALSE ENDING:	 She gave him a cookie for being so nice.
#
#
# TRUE ENDING:	 Before long, he was a happy and successful pig farmer.
# FALSE ENDING:	 Greg got a job at a competing pharmacy for more money.
#
#
# TRUE ENDING:	 The man was caught cheating.
# FALSE ENDING:	 The man was glad he didn't cheat.
#
#
# TRUE ENDING:	 Maya felt scared.
# FALSE ENDING:	 Maya started to laugh.
#
#
# TRUE ENDING:	 Gina was happy that she got to see her show.
# FALSE ENDING:	 Her mom and dad were ashamed of her.
#
#
# TRUE ENDING:	 Anna was proud of her hard work paying off.
# FALSE ENDING:	 Anna was upset about doing poorly.
#
#
# TRUE ENDING:	 Neil fed the dog all of his eggplant.
# FALSE ENDING:	 Neil then decided to eat the eggplant himself.
#
#
# TRUE ENDING:	 Cara's husband decided to go buy wood.
# FALSE ENDING:	 Cara's husband decided to go back to college.
#
#
# TRUE ENDING:	 Everyone in the class was very excited!
# FALSE ENDING:	 The teacher yelled at the girl who had tripped.
#
#
# TRUE ENDING:	 She arrived to her sister's house afterwards.
# FALSE ENDING:	 Tanya never saw her sister again.
#
#
# TRUE ENDING:	 But I do it anyway because I'm afraid he will leave me.
# FALSE ENDING:	 My husband loves to clean the dishes,
#
#
# TRUE ENDING:	 He sighed and kept watching the movie.
# FALSE ENDING:	 Joe found the movie very interesting and hated the pause button.
#
#
# TRUE ENDING:	 He said yes.
# FALSE ENDING:	 Sarah told John that she loves pineapple.
#
#
# TRUE ENDING:	 Sarah save the video.
# FALSE ENDING:	 Sarah ate all the burritos.
#
#
# TRUE ENDING:	 Amy was disappointed.
# FALSE ENDING:	 Amy thought they tasted great.
#
#
# TRUE ENDING:	 The family was glad they spotted the museum.
# FALSE ENDING:	 The family felt they had wasted their time.
#
#
# TRUE ENDING:	 Soon, Jean had two pet anoles.
# FALSE ENDING:	 Jean dropped a letter in the mailbox.
#
#
# TRUE ENDING:	 Petey was so disappointed that the game was gone.
# FALSE ENDING:	 Petey was very happy that the game was gone.
#
#
# TRUE ENDING:	 Tom was a bad sport and punched Peyton in the face.
# FALSE ENDING:	 Tom dropped to a knee and asked Peyton to marry him.
#
#
# TRUE ENDING:	 Josh revealed he was in love with Pam too.
# FALSE ENDING:	 Pam's friends won't talk to her anymore.
#
#
# TRUE ENDING:	 All got a strike and was very happy.
# FALSE ENDING:	 All was sad at the possibility of getting a strike.
#
#
# TRUE ENDING:	 Roberto liked to train others how to box.
# FALSE ENDING:	 Roberto was disappointed.
#
#
# TRUE ENDING:	 Eric then left work to go settle down.
# FALSE ENDING:	 Eric then worked harder than ever and got promoted.
#
#
# TRUE ENDING:	 She was mad when I showed it to her.
# FALSE ENDING:	 She was happy.
#
#
# TRUE ENDING:	 After that, she decided to carry mace with her when jogging.
# FALSE ENDING:	 Jane decided not to go swimming anymore.
#
#
# TRUE ENDING:	 Susie loved the goat very much.
# FALSE ENDING:	 Susie was angry at the goat.
#
#
# TRUE ENDING:	 She found a wonderful home right by her job.
# FALSE ENDING:	 Deb wanted to meet new people.
#
#
# TRUE ENDING:	 Unfortunately, it was the girl who scored well.
# FALSE ENDING:	 Both of them did not do well on the test.
#
#
# TRUE ENDING:	 They gave Tom a new latte with less ice.
# FALSE ENDING:	 They gave Tom a new latte with more ice.
#
#
# TRUE ENDING:	 Andrew said that he was going to have to find a new career.
# FALSE ENDING:	 Andrew's boss gave him a raise for his excellent performance.
#
#
# TRUE ENDING:	 The cat caught a mouse.
# FALSE ENDING:	 The cat jumped in the opposite direction.
#
#
# TRUE ENDING:	 I called my friend who loves basketball and asked him for help.
# FALSE ENDING:	 I decided to drink some margaritas that night.
#
#
# TRUE ENDING:	 I was lucky to make it to the hospital.
# FALSE ENDING:	 I prefer to take an ambulances.
#
#
# TRUE ENDING:	 Kyrie yelped and ran away from her cat.
# FALSE ENDING:	 Kyrie and the mouse then played.
#
#
# TRUE ENDING:	 Billy exchanged several of his coins for the baseball.
# FALSE ENDING:	 Billy told the boy the baseball was stupid.
#
#
# TRUE ENDING:	 Kim had body image issues.
# FALSE ENDING:	 Kim loved her body shape.
#
#
# TRUE ENDING:	 Lucy was ecstatic!
# FALSE ENDING:	 Lucy was so disappointed.
#
#
# TRUE ENDING:	 Sitting on her bed was a small, grey kitten.
# FALSE ENDING:	 Jill ran for president.
#
#
# TRUE ENDING:	 Ben was devastated.
# FALSE ENDING:	 Ben decided to become a commercial driver.
#
#
# TRUE ENDING:	 Kimmy was very excited.
# FALSE ENDING:	 Kim vowed to never return to Paris.
#
#
# TRUE ENDING:	 Colin made lots of friends.
# FALSE ENDING:	 All the kids at Colin's school hated him.
#
#
# TRUE ENDING:	 I'm sure I'll figure out a place for it eventually.
# FALSE ENDING:	 The picture has a very nice frame, in my opinion.
#
#
# TRUE ENDING:	 We are happy about having a child.
# FALSE ENDING:	 We are sad about having a child.
#
#
# TRUE ENDING:	 Bob believed that there were good people in the world.
# FALSE ENDING:	 Bob contemplated how unfriendly the world was.
#
#
# TRUE ENDING:	 When they exited the cafe, Casey confronted Tom.
# FALSE ENDING:	 Casey congratulated Tom and Susan when they came out.
#
#
# TRUE ENDING:	 I decided to head to Starbucks instead.
# FALSE ENDING:	 I never drank coffee.
#
#
# TRUE ENDING:	 Sarah then happily watched the show.
# FALSE ENDING:	 Sarah could not find anything to watch.
#
#
# TRUE ENDING:	 Benny's team won the title.
# FALSE ENDING:	 Benny decided to quit running.
#
#
# TRUE ENDING:	 Danny never ate peas again.
# FALSE ENDING:	 Danny asked for more peas.
#
#
# TRUE ENDING:	 I was so happy when I made it back to my house.
# FALSE ENDING:	 I could not find my way back from the post office.
#
#
# TRUE ENDING:	 The teacher eventually stopped putting her pencil cup out.
# FALSE ENDING:	 The teacher rewarded everyone with candy.
#
#
# TRUE ENDING:	 Tom decided to buy more racing games to enjoy the wheel with.
# FALSE ENDING:	 Tom broke the wheel because he didn't like racing games.
#
#
# TRUE ENDING:	 Kevin and his girlfriend liked doing things together.
# FALSE ENDING:	 Kevin and his girlfriend never got along.
#
#
# TRUE ENDING:	 My cousins sued the water company.
# FALSE ENDING:	 My cousins started drinking more water.
#
#
# TRUE ENDING:	 She saved enough money to buy a cell phone on her own.
# FALSE ENDING:	 Kim saved up enough money to buy a used car.
#
#
# TRUE ENDING:	 Gina changed her mind after the bully walked by and hit her.
# FALSE ENDING:	 Gina got her pilot's license the next day.
#
#
# TRUE ENDING:	 Jake bought 15 shirts.
# FALSE ENDING:	 He bought 10 pairs of pants.
#
#
# TRUE ENDING:	 My brother freaked out.
# FALSE ENDING:	 My brother kept it that way.
#
#
# TRUE ENDING:	 Don had a great time skating for the first time.
# FALSE ENDING:	 Don went to eat chicken wings.
#
#
# TRUE ENDING:	 Brian and his girlfriend had sex after they got home.
# FALSE ENDING:	 Brian's girlfriend left him.
#
#
# **********VALIDATION SET**********
#
# TRUE ENDING:	 He is happy now.
# FALSE ENDING:	 He joined a gang.
#
#
# TRUE ENDING:	 The brownies are so delicious Laverne eats two of them.
# FALSE ENDING:	 Laverne doesn't go to her friend's party.
#
#
# TRUE ENDING:	 Sarah decided that she preferred her home over Europe.
# FALSE ENDING:	 Sarah then decided to move to Europe.
#
#
# TRUE ENDING:	 Gina liked the cookies so much she ate them all in one sitting.
# FALSE ENDING:	 Gina gave the cookies away at her church.
#
#
# TRUE ENDING:	 I was very proud of my performance.
# FALSE ENDING:	 I was very ashamed of my performance.
#
#
# TRUE ENDING:	 I never gave the man money again.
# FALSE ENDING:	 The next day I gave the man twenty dollars.
#
#
# TRUE ENDING:	 Jim took time to decide what he would take a picture of.
# FALSE ENDING:	 Jim took 20 more photos.
#
#
# TRUE ENDING:	 His boss commends him for a job well done.
# FALSE ENDING:	 Ron is immediately fired for insubordination.
#
#
# TRUE ENDING:	 In Vegas, John and Billy competed against eighty contestants.
# FALSE ENDING:	 John and Billy were disappointed.
#
#
# TRUE ENDING:	 Later, she passed the test.
# FALSE ENDING:	 But she gave up.
#
#
# TRUE ENDING:	 Eventually Trish grudgingly came to accept nature.
# FALSE ENDING:	 The fish had very interesting mating habits.
#
#
# TRUE ENDING:	 When Corey came to, both the man and his car were gone.
# FALSE ENDING:	 Corey didn't mind at all.
#
#
# TRUE ENDING:	 Marcy gave her boyfriend a big kiss and said yes.
# FALSE ENDING:	 Marcy shrugged her shoulders and reached for the TV remote.
#
#
# TRUE ENDING:	 Cara decided to eat at the food cart every week.
# FALSE ENDING:	 Cara told the owner that the food was awful.
#
#
# TRUE ENDING:	 Tony enjoyed going on the cruise.
# FALSE ENDING:	 Tony was scared of the ocean.
#
#
# TRUE ENDING:	 Ignacio won a silver medal.
# FALSE ENDING:	 Ignacio gave up swimming.
#
#
# TRUE ENDING:	 They prepared for the start of the race.
# FALSE ENDING:	 Danny decided to go to sleep.
#
#
# TRUE ENDING:	 Mary couldn't wait to present her report.
# FALSE ENDING:	 Mary disliked Pandas.
#
#
# TRUE ENDING:	 Ellen ended up winning the prize.
# FALSE ENDING:	 Ellen had to pay a replacement fee for her library card.
#
#
# TRUE ENDING:	 Jesse was picked on by the other boys in school.
# FALSE ENDING:	 Jesse went to the park with his new friend, Roger.
#
#
# TRUE ENDING:	 She was in pain but happy to not have to go to work.
# FALSE ENDING:	 Tiffany went in to work the next day.
#
#
# TRUE ENDING:	 She found her phone in the car.
# FALSE ENDING:	 But she didn't want her phone anymore.
#
#
# TRUE ENDING:	 Alice called her mother and apologized profusely.
# FALSE ENDING:	 Alice messaged a cute guy she saw on Tinder.
#
#
# TRUE ENDING:	 Ted continues to watch several movies a week.
# FALSE ENDING:	 He decides to stop watching movies.
#
#
# TRUE ENDING:	 She loved it so much she planned a trip for the next week.
# FALSE ENDING:	 She was shot and vowed to never go there again.
#
#
# TRUE ENDING:	 But then he misses his old phone.
# FALSE ENDING:	 Javier decides to get a smartphone.
#
#
# TRUE ENDING:	 Rachel broke down in tears.
# FALSE ENDING:	 Rachel started moonwalking with excitement.
#
#
# TRUE ENDING:	 Ron applauded the officer's performance.
# FALSE ENDING:	 Ron started collecting bottle caps.
#
#
# TRUE ENDING:	 Sam went on a diet.
# FALSE ENDING:	 Sam was happy.
#
#
# TRUE ENDING:	 Larry became careful.
# FALSE ENDING:	 Larry loved going to the hospital.
#
#
# TRUE ENDING:	 Soon we were boyfriend and girlfriend and thinking of marriage.
# FALSE ENDING:	 We broke up right away.
#
#
# TRUE ENDING:	 It worked for Sammy.
# FALSE ENDING:	 Sammy was not that into coffee.
#
#
# TRUE ENDING:	 Jared swerved quickly and managed to avoid a collision.
# FALSE ENDING:	 Jared decided to accelerate.
#
#
# TRUE ENDING:	 Bobby found the time passed quickly.
# FALSE ENDING:	 Bobby asked to be taken to a restaurant.
#
#
# TRUE ENDING:	 Joe thought about working in the garden as he ate the yummy soup.
# FALSE ENDING:	 Joe dumped the pot outside because he hated soup.
#
#
# TRUE ENDING:	 Aliza was sad, but she never contacted him again.
# FALSE ENDING:	 He fell in love with Aliza and they were married.
#
#
# TRUE ENDING:	 Lina felt a new appreciation for candy canes.
# FALSE ENDING:	 Lina now knew that candy canes were boring.
#
#
# TRUE ENDING:	 They were very friendly.
# FALSE ENDING:	 I threw the kickball through their closed window.
#
#
# TRUE ENDING:	 By Sunday night, Bev was exhausted again.
# FALSE ENDING:	 Bev got the mail and fed the fish, just like she did every day.
#
#
# TRUE ENDING:	 She became a better cook.
# FALSE ENDING:	 She never cooked again.
#
#
# TRUE ENDING:	 We had a great pizza at Frank Pepe's pizza shop.
# FALSE ENDING:	 We walked 5 growling dogs at the park across town.
#
#
# TRUE ENDING:	 Bernice decided to get an airplane ticket and reserve a room.
# FALSE ENDING:	 Bernice went to Europe for her birthday.
#
#
# TRUE ENDING:	 He was surprised but thankful.
# FALSE ENDING:	 Jim thought he was crazy and left.
#
#
# TRUE ENDING:	 Randy told his friend how relieved he was he found it.
# FALSE ENDING:	 Randy saw the house but kept on driving and didn't come back.
#
#
# TRUE ENDING:	 I felt very badly for my brother.
# FALSE ENDING:	 Watching my brother crash was fun.
#
#
# TRUE ENDING:	 Anna felt very fashionable when she left the salon.
# FALSE ENDING:	 Anna really liked her new hairstyle.
#
#
# TRUE ENDING:	 Sarah was glad they were able to catch up.
# FALSE ENDING:	 Sarah and david went to go get dinner right after that.
#
#
# TRUE ENDING:	 AJ let out a sigh of relief.
# FALSE ENDING:	 AJ then began to feel sad.
#
#
# TRUE ENDING:	 Joe was happy the shirt fit.
# FALSE ENDING:	 Joe hated rock music afterwards.
#
#
# TRUE ENDING:	 Priya thought her food was delicious.
# FALSE ENDING:	 Priya decided not to eat and left.
#
#
# TRUE ENDING:	 Karen became good friends with her roommate.
# FALSE ENDING:	 Karen hated her roommate.
#
#
# TRUE ENDING:	 Eventually I healed.
# FALSE ENDING:	 I found I loved being swollen.
#
#
# TRUE ENDING:	 John was very excited.
# FALSE ENDING:	 John was very upset with his wife.
#
#
# TRUE ENDING:	 Donald hoped this foolishness won him the election.
# FALSE ENDING:	 Don hated elections.
#
#
# TRUE ENDING:	 They were divorced a few months later.
# FALSE ENDING:	 They fell back in love and stayed together forever.
#
#
# TRUE ENDING:	 The vet treated her cat's cancer the best they could.
# FALSE ENDING:	 Rachel was excited to hear the news.
#
#
# TRUE ENDING:	 Jim is very upset.
# FALSE ENDING:	 Jim was happy to see the officer.
#
#
# TRUE ENDING:	 It turned out I was allergic to avocados.
# FALSE ENDING:	 He said I was paranoid, and charged me $100.
#
#
# TRUE ENDING:	 David then had his manuscript published.
# FALSE ENDING:	 David then uploaded his new video.
#
#
# TRUE ENDING:	 Boris realized he was wasting his life.
# FALSE ENDING:	 Boris decided to wear the dress.
#
#
# TRUE ENDING:	 The police officer eventually got better.
# FALSE ENDING:	 The police officer had to give up his badge and gun.
#
#
# TRUE ENDING:	 Jennifer was not hungry anymore.
# FALSE ENDING:	 Jennifer wanted more food.
#
#
# TRUE ENDING:	 When Nathan returned, his mom apologized for being so mean.
# FALSE ENDING:	 When Nathan returned, he felt very happy for the exercise.
#
#
# TRUE ENDING:	 Jeremiah reconsiders career paths.
# FALSE ENDING:	 Jeremiah continues to work outside.
#
#
# TRUE ENDING:	 The people chased the wolf away and the two women were fine.
# FALSE ENDING:	 The two women fell off a cliff.
#
#
# TRUE ENDING:	 Gary's parents were relieved to find him.
# FALSE ENDING:	 Gary's parents were disappointed to find him.
#
#
# TRUE ENDING:	 Timmy then had to find another job,
# FALSE ENDING:	 Timmy was promoted for working so much all the time.
#
#
# TRUE ENDING:	 My favorite card game was poker.
# FALSE ENDING:	 My time with the minister was very useful.
#
#
# TRUE ENDING:	 Amber was so hurried she left the list at home.
# FALSE ENDING:	 Amber enjoyed a relaxing two hour brunch.
#
#
# TRUE ENDING:	 Eve thought the couch was very comfortable.
# FALSE ENDING:	 She bought a new couch to replace it.
#
#
# TRUE ENDING:	 He found a very large spider there.
# FALSE ENDING:	 Jason took a hot shower.
#
#
# TRUE ENDING:	 Linda and the coworker ended up being best friends.
# FALSE ENDING:	 Her boss fired her the next day.
#
#
# TRUE ENDING:	 All of the presents were wrapped and stored for the holidays.
# FALSE ENDING:	 She returned all of the presents for cheaper ones.
#
#
# TRUE ENDING:	 She was able to get off drugs after some time.
# FALSE ENDING:	 When she arrived, she did drugs all day.
#
#
# TRUE ENDING:	 He realizes he might have to apply for public assistance.
# FALSE ENDING:	 He is thrilled about his new responsibilities at work.
#
#
# TRUE ENDING:	 Miranda quits her job.
# FALSE ENDING:	 Miranda decides to take on a second job.
#
#
# TRUE ENDING:	 They reported the babysitter to the police.
# FALSE ENDING:	 They gave the baby sitter a good review.
#
#
# TRUE ENDING:	 Bobby had a good party.
# FALSE ENDING:	 Bobby was mad at his friends.
#
#
# TRUE ENDING:	 We want to revisit someday.
# FALSE ENDING:	 We all vowed to never go back again.
#
#
# TRUE ENDING:	 They then put their clothes up neatly.
# FALSE ENDING:	 The clothes were filthy and unfolded.
#
#
# TRUE ENDING:	 Timmy spent all day cleaning so he could watch tv.
# FALSE ENDING:	 Timmy went to the mess hall for breakfast.
#
#
# TRUE ENDING:	 My daughter was excited.
# FALSE ENDING:	 My daughter was disappointed.
#
#
# TRUE ENDING:	 Craig did it one too many times and the patrons beat him up.
# FALSE ENDING:	 Craig won the poker match without much trouble.
#
#
# TRUE ENDING:	 Pam was a good hostess.
# FALSE ENDING:	 Pam was a lousy hostess.
#
#
# TRUE ENDING:	 Ellen was appalled.
# FALSE ENDING:	 Ellen liked the negative attention.
#
#
# TRUE ENDING:	 Jim decided to devise a plan for repayment.
# FALSE ENDING:	 Jim decided to open another credit card.
#
#
# TRUE ENDING:	 Tim won the baking contest.
# FALSE ENDING:	 The judges vomited from the taste of the donuts.
#
#
# TRUE ENDING:	 Now I don't try to make him wear training pants.
# FALSE ENDING:	 Child protection services removed him from the home.
#
#
# TRUE ENDING:	 She was relieved that it didn't hit anything.
# FALSE ENDING:	 She went outside to fly a kite.
#
#
# TRUE ENDING:	 It broke and Jill felt dumb for believing the hype.
# FALSE ENDING:	 The cloth ripped in two, much to Jill's surprise.
#
#
# TRUE ENDING:	 Addie was relieved and took deep breaths to calm herself.
# FALSE ENDING:	 Addie was put in jail for her crime.
#
#
# TRUE ENDING:	 The manager wanted Sean to understand everything.
# FALSE ENDING:	 The manager hoped Sean would perform badly.
#
#
# TRUE ENDING:	 Fred ended up winning the bet, and the $100.
# FALSE ENDING:	 Fred cancelled the bet at the end of the month.
#
#
# TRUE ENDING:	 When he woke up, he had already landed.
# FALSE ENDING:	 John loved every second of the skydiving trip.
#
#
# TRUE ENDING:	 Gina loved her grandma.
# FALSE ENDING:	 Gina hated her grandma.
#
#
# TRUE ENDING:	 It was kind of expensive but she decided it was worth it.
# FALSE ENDING:	 She couldn't resist so she bought the antique vase.
#
#
# TRUE ENDING:	 It had been a very fun day.
# FALSE ENDING:	 Tyler felt like his parents never let him do anything.
#
#
# TRUE ENDING:	 After all his practice this week, Jimmy has learned a new trick.
# FALSE ENDING:	 Jimmy has decided to give away his skateboard.
#
#
# TRUE ENDING:	 Maxine gets laser removal next time.
# FALSE ENDING:	 Maxine doesn't want to go on the date.
#
#
# TRUE ENDING:	 Ryan loved how his bike looked.
# FALSE ENDING:	 Ryan decided not to ride his bike anymore.
#
#
# TRUE ENDING:	 The sauce burned and stuck to the bottom of the pan.
# FALSE ENDING:	 It took forever for the sauce to heat up.
#
#
# TRUE ENDING:	 Nick beat his girlfriend and she gave him the five dollars.
# FALSE ENDING:	 Nick gave up because he didn't care if his girlfriend won.
#
#
# TRUE ENDING:	 We felt pleased with our performance.
# FALSE ENDING:	 We felt we had performed badly.
#
#
# TRUE ENDING:	 Michelle named the cat, "Socks."
# FALSE ENDING:	 Michelle gave the cat to her neighbor.
#
#
# TRUE ENDING:	 Neil enjoyed Ireland.
# FALSE ENDING:	 Neil decided never to return to Ireland.
#
#
# TRUE ENDING:	 Mary was upset that her dress was ruined.
# FALSE ENDING:	 Mary was happy to be showing off her dress.
#
#
# TRUE ENDING:	 Scott apprehended the perpetrator.
# FALSE ENDING:	 Scott gave him a high five.
#
#
# TRUE ENDING:	 I went to bed and then rested until morning.
# FALSE ENDING:	 I felt like I could run a marathon.
#
#
# TRUE ENDING:	 Colin stuck to his budget and only drank 2 beers.
# FALSE ENDING:	 Colin drinks beer at the bar all night.
#
#
# TRUE ENDING:	 Sally was forced to go hungry.
# FALSE ENDING:	 Sally then bought a large breakfast.
#
#
# TRUE ENDING:	 Jordan knew some conversational Spanish by the time he moved.
# FALSE ENDING:	 Jordan didn't like fish tacos at all.
#
#
# TRUE ENDING:	 After a lot of searching, Tim and Anna found the perfect name.
# FALSE ENDING:	 Tim and Anna decided they would ask their veterinarian.
#
#
# TRUE ENDING:	 He was happy with his decision.
# FALSE ENDING:	 He never worked out again.
#
#
# TRUE ENDING:	 She finally got her chance to play in the match.
# FALSE ENDING:	 She asked the coach to find someone else.
#
#
# TRUE ENDING:	 The doctor told Tim that Ellen was finally pregnant.
# FALSE ENDING:	 The doctor told Tim that Emily went for a run.
#
#
# TRUE ENDING:	 David promised to be more careful in the future.
# FALSE ENDING:	 David ate a cheeseburger.
#
#
# TRUE ENDING:	 Neil played in the competition.
# FALSE ENDING:	 Neil played baseball.
#
#
# TRUE ENDING:	 I still miss my baby blanket.
# FALSE ENDING:	 I sleep with my baby blanket every night.
#
#
# TRUE ENDING:	 Cam has since decided to insure his belongings.
# FALSE ENDING:	 Afterwards, Cam was able to sell more books than he ever had.
#
#
# TRUE ENDING:	 Rosie's teacher loved the gift.
# FALSE ENDING:	 Rosie's teacher gave her detention.
#
#
# TRUE ENDING:	 The company fixed his fridge.
# FALSE ENDING:	 The company fixed his television.
#
#
# TRUE ENDING:	 The man is furious.
# FALSE ENDING:	 Ebay is a very reputable company.
#
#
# TRUE ENDING:	 It cost a lot of money, but he got it repaired.
# FALSE ENDING:	 Tom knew it would be expensive to repair his boat.
#
#
# TRUE ENDING:	 Harry had a great time at the park.
# FALSE ENDING:	 Harry didn't like theme parks.
#
#
# TRUE ENDING:	 The teacher agreed to discuss it with me.
# FALSE ENDING:	 My teacher suggested I pursue art school.
#
#
# TRUE ENDING:	 The game was canceled.
# FALSE ENDING:	 Leah was very happy to hear the news.
#
#
# TRUE ENDING:	 She was happy to see her wrinkles were gone.
# FALSE ENDING:	 She decided to buy more toothpaste.
#
#
# TRUE ENDING:	 Annoyed, he contacted the retailer to complain about the damage.
# FALSE ENDING:	 Harry spent the evening happily taking pictures.
#
#
# TRUE ENDING:	 Jasper enjoys cutting dead animals.
# FALSE ENDING:	 Jasper quits his job the next day.
#
#
# TRUE ENDING:	 I loved throwing parties.
# FALSE ENDING:	 I couldn't wait for my friends to leave.
#
#
# TRUE ENDING:	 He finally received a job offer.
# FALSE ENDING:	 Tom was sad about leaving his miserable job.
#
#
# TRUE ENDING:	 They had a great tea party.
# FALSE ENDING:	 Linda's classmate wanted her to leave.
#
#
# TRUE ENDING:	 They bought lots of clothes.
# FALSE ENDING:	 Ashley couldn't buy anything because she was broke.
#
#
# TRUE ENDING:	 Paul got a job.
# FALSE ENDING:	 Paul was furious with his mom.
#
#
# TRUE ENDING:	 They all sat with their mouths open as Harvey beat them all.
# FALSE ENDING:	 Harvey choked, and lost every match he played.
#
#
# TRUE ENDING:	 I then realized that I was not good at math.
# FALSE ENDING:	 Then I knew that I was great at math!
#
#
# TRUE ENDING:	 They bought another red car.
# FALSE ENDING:	 My parents bought matching mopeds.
#
#
# TRUE ENDING:	 She acted like a brat and threw a tantrum.
# FALSE ENDING:	 Gina doesn't care about electronics.
#
#
# TRUE ENDING:	 I realized it had only been the wind.
# FALSE ENDING:	 I realized I needed noise to sleep.
#
#
# TRUE ENDING:	 Gina decided to walk instead.
# FALSE ENDING:	 Gina and her mother went immediately.
#
#
# TRUE ENDING:	 He now loves to go hunting.
# FALSE ENDING:	 He then went to sleep.
#
#
# TRUE ENDING:	 He'd dug in the trash for nothing.
# FALSE ENDING:	 Jay thought Burger King was awesome.
#
#
# TRUE ENDING:	 John was a troubled worker.
# FALSE ENDING:	 John was an outstanding worker.
#
#
# TRUE ENDING:	 KIm breathlessly saved the child.
# FALSE ENDING:	 Kim saved the cart but let the child go.
#
#
# TRUE ENDING:	 Kev decided not to come hunting.
# FALSE ENDING:	 Kev was excited to try out his new gun.
#
#
# TRUE ENDING:	 This was the best birthday gift Emily had ever had.
# FALSE ENDING:	 Emily decided she didn't want the concert ticket.
#
#
# TRUE ENDING:	 Lina loved her new job.
# FALSE ENDING:	 Lina hated donuts.
#
#
# TRUE ENDING:	 I was tired when I got home.
# FALSE ENDING:	 I was invigorated when I got home.
#
#
# TRUE ENDING:	 The new forum was theirs to rule.
# FALSE ENDING:	 They returned to the forum later because they liked it so much.
#
#
# TRUE ENDING:	 Donna had a much easier time because Ty was asleep.
# FALSE ENDING:	 Donna wished I would wake up.
#
#
# TRUE ENDING:	 Gina felt more calm once she arrived in the library.
# FALSE ENDING:	 Gina was angry that she went to the library.
#
#
# TRUE ENDING:	 Vivienne was not granted a visa.
# FALSE ENDING:	 Vivienne soon received her visa in the mail.
#
#
# TRUE ENDING:	 Frank bought a water gun the next day.
# FALSE ENDING:	 Frank enrolled in a marine biology class.
#
#
# TRUE ENDING:	 Matt was excited to be so lucky.
# FALSE ENDING:	 Matt was frustrated about what he found.
#
#
# TRUE ENDING:	 Gina felt guilty about forgetting everyone's toothbrushes.
# FALSE ENDING:	 Gina's family was glad that their toothbrushes weren't packed.
#
#
# TRUE ENDING:	 The manager decided to offer John the job.
# FALSE ENDING:	 John commented on how badly run he thought the place was.
#
#
# TRUE ENDING:	 Ben made freshly squeezed orange juice from the oranges.
# FALSE ENDING:	 Ben sipped his apple juice contently.
#
#
# TRUE ENDING:	 Reg hoped he would get another snow day soon.
# FALSE ENDING:	 Reg hoped it would never snow again.
#
#
# TRUE ENDING:	 Caroline opened the soda and drank it all in one gulp!
# FALSE ENDING:	 Caroline refused to open the soda.
#
#
# TRUE ENDING:	 Tom enjoyed the roasted marshmallows.
# FALSE ENDING:	 Tom got up and went for a swim.
#
#
# TRUE ENDING:	 The man at the deli apologized.
# FALSE ENDING:	 The man at the deli said the sandwich would cost more now.
#
#
# TRUE ENDING:	 He promised to pay her back.
# FALSE ENDING:	 Bob ran away in terror.
#
#
# TRUE ENDING:	 John was surprised.
# FALSE ENDING:	 John did not have a gun.
#
#
# TRUE ENDING:	 Neil had an amazing educational and cultural experience.
# FALSE ENDING:	 Neil was not interested in Egyptian history.
#
#
# TRUE ENDING:	 John ate, but told his mom that he never wanted to eat it again.
# FALSE ENDING:	 John knew his papaya farm needed new capital investment.
#
#
# TRUE ENDING:	 Eventually it turned up.
# FALSE ENDING:	 All my socks were accounted for.
#
#
# TRUE ENDING:	 Alex resolved to always check his shoelaces before leaving.
# FALSE ENDING:	 Alex next ran for a seat on the school board.
#
#
# TRUE ENDING:	 Over time she became really good.
# FALSE ENDING:	 Before long Nina was the best basketball player in the state.
#
#
# TRUE ENDING:	 And thus Sal gave up on magic.
# FALSE ENDING:	 The people watching him congratulated him.
#
#
# TRUE ENDING:	 Lisa loved to bake.
# FALSE ENDING:	 Lisa hated baking.
#
#
# TRUE ENDING:	 Javier began playing handball with them regularly.
# FALSE ENDING:	 Javier went to the convenience store after school.
#
#
# TRUE ENDING:	 He bought a big package of AA batteries.
# FALSE ENDING:	 He bought another remote control car for himself.
#
#
# TRUE ENDING:	 Eventually it stopped snowing.
# FALSE ENDING:	 Mim pulled back onto the road and drove faster to make up time.
#
#
# TRUE ENDING:	 We went home without buying anything.
# FALSE ENDING:	 We brought home six bags of items.
#
#
# TRUE ENDING:	 Betsy had to be taken to the hospital to be fitted with a cast.
# FALSE ENDING:	 Betsy played tennis afterward.
#
#
# TRUE ENDING:	 Her fear melted away as she swung.
# FALSE ENDING:	 The swing was pulled around violently in the wind.
#
#
# TRUE ENDING:	 The Malamute eventually tried to slide down the slide.
# FALSE ENDING:	 The Malamute's owner never took him to the slide again.
#
#
# TRUE ENDING:	 Tim was very happy to be remembered.
# FALSE ENDING:	 Tim was annoyed by the attention.
#
#
# TRUE ENDING:	 Frankie found another man.
# FALSE ENDING:	 Frankie went to see a movie.
#
#
# TRUE ENDING:	 Nancy began to cry and felt humiliated.
# FALSE ENDING:	 Nancy caught the pie and began to eat it.
#
#
# TRUE ENDING:	 He eagerly applied for it and was ultimately hired.
# FALSE ENDING:	 So he decided to go home early that day and quit his internship.
#
#
# TRUE ENDING:	 Kevin bought a house.
# FALSE ENDING:	 Kevin used the money that he had saved to buy a sports car.
#
#
# TRUE ENDING:	 Joe asked the accountant what happened.
# FALSE ENDING:	 Joe went for a run on the beach.
#
#
# TRUE ENDING:	 Sven was caught and jailed shortly after.
# FALSE ENDING:	 Sven donated the money to charity.
#
#
# TRUE ENDING:	 John eventually beat the cancer.
# FALSE ENDING:	 John hoped he would not get well.
#
#
# TRUE ENDING:	 He stayed heart attack free for the rest of his life.
# FALSE ENDING:	 Matt celebrated leaving the hospital with a large steak.
#
#
# TRUE ENDING:	 Both dogs enjoyed playing together, anyway.
# FALSE ENDING:	 The cats made a mess out of the house!
#
#
# TRUE ENDING:	 I had a hard time falling asleep that night.
# FALSE ENDING:	 Overall I was dissatisfied with the night.
#
#
# TRUE ENDING:	 The dogs seemed happy to stay together.
# FALSE ENDING:	 Louie walked across the sandy beach, lonely.
#
#
# TRUE ENDING:	 She started losing weight.
# FALSE ENDING:	 She gained 50 pounds.
#
#
# TRUE ENDING:	 It came out sparkling.
# FALSE ENDING:	 I decided to throw the ring away.
#
#
# TRUE ENDING:	 Gina was so touched she cried when they gave it to her.
# FALSE ENDING:	 Gina stopped volunteering because she felt unappreciated.
#
#
# TRUE ENDING:	 Tom was happy to have a kid.
# FALSE ENDING:	 She never told Tom.
#
#
# TRUE ENDING:	 Gina was disgusted.
# FALSE ENDING:	 Gina continued to stare.
#
#
# TRUE ENDING:	 They played ball for the rest of the afternoon.
# FALSE ENDING:	 Greg was more bored than ever.
#
#
# TRUE ENDING:	 Pamela received a full refund and a free urn for her troubles.
# FALSE ENDING:	 Pamela was happy about her purchase.
#
#
# TRUE ENDING:	 Jane was disappointed she had to stay and clean the office.
# FALSE ENDING:	 Jane was happy she had to stay and clean the office.
#
#
# TRUE ENDING:	 Kate was pleased!
# FALSE ENDING:	 Kate was disappointed.
#
#
# TRUE ENDING:	 We will never rent from that car company again.
# FALSE ENDING:	 We look forward to renting from that same car company again.
#
#
# TRUE ENDING:	 Frank will save about $25 a week making coffee himself.
# FALSE ENDING:	 Frank switched to tea and donated the coffee maker.

# %%
#Vocabulary class courtesy of HW4

class MyVocabulary:
    def __init__(self, special_tokens=None):
        self.w2idx = {}
        self.idx2w = {}
        self.w2cnt = defaultdict(int)
        self.special_tokens = special_tokens
        if self.special_tokens is not None:
            self.add_tokens(special_tokens)

    def add_tokens(self, tokens):
        for token in tokens:
            self.add_token(token)
            self.w2cnt[token] += 1

    def add_token(self, token):
        if token not in self.w2idx:
            cur_len = len(self)
            self.w2idx[token] = cur_len
            self.idx2w[cur_len] = token

    def prune(self, min_cnt=2):
        to_remove = set([token for token in self.w2idx if self.w2cnt[token] < min_cnt])
        #print(set(self.special_tokens))
        
        #INSERTED THESE CHANGES MYSELF
        for token in self.special_tokens:
            if token in to_remove:
                to_remove.remove(token)
        #THE ORIGINAL CODE IN PRUNE WAS REMOVING <PAD> FROM THE VOCAB
        #to_remove ^= set(self.special_tokens)
        #print('<PAD>' in to_remove,self.w2cnt['<PAD>'])

        for token in to_remove:
            self.w2cnt.pop(token)

        self.w2idx = {token: idx for idx, token in enumerate(self.w2cnt.keys())}
        self.idx2w = {idx: token for token, idx in self.w2idx.items()}
        
        #print("Pad in w2cnt", '<PAD>' in self.w2cnt)
        #print("Pad in w2idx", '<PAD>' in self.w2idx)
        #print("Pad in idx2w", self.idx2w[0] is '<PAD>')
        #print(self.w2idx['<PAD>'])

    def __contains__(self, item):
        return item in self.w2idx

    def __getitem__(self, item):
        if isinstance(item, str):
            return self.w2idx[item]
        elif isinstance(item , int):
            return self.idx2w[item]
        else:
            raise TypeError("Supported indices are int and str")

    def __len__(self):
        return(len(self.w2idx))

# %%
#Text classification dataset from HW4
#manually set max length of sentence to 13. arbitrarily chosen number

class TextClassificationDataset(torch.utils.data.Dataset):
    def __init__(self, texts, labels, vocab=None, labels_vocab=None, max_len=13, lowercase=True):
        """
        Args:
            texts (list of str): texts of the dataset examples
            labels (list of str): the correponding labels of the dataset examples
            vocab (MyVocabulary, optional): vocabular to convert text to indices. If not provided, will be created based on the texts
            labels_vocab (MyVocabulary, optional): vocabular to convert labels to indices. If not provided, will be created based on the labels
            max_len (int): maximum length of the text. Texts shorter than max_len will be cut at the end
            lowercase (bool, optional): a fag specifying whether or not the input text should be lowercased
        """
        
        self.max_len = max_len
        self.lowercase = lowercase
        

        self.texts = [self._preprocess(t, max_len=max_len, lowercase=lowercase) for t in texts]
        self.labels = labels

        if vocab is None:
            vocab = MyVocabulary(['<PAD>', '<UNK>'])
            for text in self.texts:
                vocab.add_tokens(text)
            
        if labels_vocab is None:
            labels_vocab = MyVocabulary()
            labels_vocab.add_tokens(labels)
            
        self.vocab = vocab
        self.labels_vocab = labels_vocab
        
    def _preprocess(self, text, max_len=None, lowercase=True):
        """
        Preprocess a give dataset example
        Args:
            text (str): given dataset example
            max_len (int, optional): maximum sequence length
            lowercase (bool, optional): a fag specifying whether or not the input text should be lowercased
        
        Returns:
            a list of tokens for a given text span
        """ 
        ### YOUR CODE BELOW ###
        if lowercase:
            text = text.lower()
        # tokenize the input text
       
        tokens = []
        tokens = word_tokenize(text)
        
        # cut the list of tokens to `max_len` if needed 
        if len(tokens) > max_len:
            del tokens[max_len:]
        tokens = self._pad(tokens)
        ### YOUR CODE ABOVE ###
        return tokens
    
    def _pad(self, tokens):
        """
        Pad tokens to self.max_len
        Args:
            tokens (list): a list of str tokens for a given example
            
        Returns:
            list: a padded list of str tokens for a given example
        """
        # pad the list of tokens to be exactly of the `max_len` size
        ### YOUR CODE BELOW ###
        if len(tokens) < self.max_len:
            for i in range(len(tokens), self.max_len):
                tokens.append("<PAD>") 
        ### YOUR CODE ABOVE ###
        return tokens

    def __getitem__(self, idx):
        """
        Given an index, return a formatted dataset example
        
        Args:
            idx (int): dataset index
            
        Returns:
            tuple: a tuple of token_ids based on the vocabulary mapping  and a corresponding label
        """
        ### YOUR CODE BELOW ###
        tokens = []
        words = self.texts[idx]
        for word in words:
            if word not in self.vocab.w2cnt:
                #print(word)
                tokens.append(self.vocab.w2idx['<UNK>'])
            elif word != '<PAD>':
                tokens.append(self.vocab.w2idx[word])
            elif word == '<PAD>':
                tokens.append(self.vocab.w2idx["<PAD>"])
                #print("found pad")
        label = self.labels[idx]
        ### YOUR CODE ABOVE ###
        
        return  np.asarray(tokens), np.asarray(self.labels_vocab.w2idx[label])

    def __len__(self):
        return len(self.texts)

# %%
import random
random.shuffle(test_set)
random.shuffle(val_set)


data_train = []
labels_train = []

data_test, labels_test = zip(*test_set)
data_train, labels_train = zip(*val_set)

print(data_train[0],labels_train[0])
# Out:
# Janice is now an expert walnut cracker. Coherent

# %%
dataset_train = TextClassificationDataset(data_train, labels_train)
dataset_test = TextClassificationDataset(data_test, labels_test, vocab=dataset_train.vocab, labels_vocab=dataset_train.labels_vocab)

# %%
print(len(dataset_train.vocab.w2cnt), "words before pruning")
dataset_train.vocab.prune()
print(len(dataset_train.vocab.w2cnt),"words after pruning")
# Out:
# 3880 words before pruning
# 2110 words after pruning

# %%
#Glove embeddings
#initialize model embedding matrix with glove embeddings
embedding_dim = len(dataset_train.vocab)
glove_matrix = torch.nn.Embedding(embedding_dim, 300)

with open("glove.6B.300d.txt", "r") as glove:
    for line in glove:
        if len(line.split()) > 301:
            continue#skip words with spaces
        if line.split()[0] in dataset_train.vocab.w2idx:
            weight = np.array([float(t) for t in line.strip().split()[1:]])
            glove_matrix.weight.data[dataset_train.vocab.w2idx[line.split()[0]]] = torch.FloatTensor(weight)

# %%
class TextClassificationModel(torch.nn.Module):
    def __init__(self, embedding_size, vocab_size, hidden_size, nb_classes, pretrained_embeddings):
        super().__init__()
        
        self.embedding_size = embedding_size
        self.hidden_size = hidden_size
        self.nb_classes = nb_classes

        ### YOUR CODE BELOW ###
        self.embeddings = pretrained_embeddings
        
        #self.LSTM = torch.nn.LSTM(input_size=embedding_size, hidden_size=self.hidden_size, bidirectional = False)
        #self.projection = torch.nn.Linear(hidden_size * 2, nb_classes)
        
        self.LSTM = torch.nn.LSTM(input_size=embedding_size, hidden_size=self.hidden_size, bidirectional = False)
        self.projection = torch.nn.Linear(hidden_size, nb_classes)
        
        self.dropout = torch.nn.Dropout(0.5)
        ### YOUR CODE ABOVE ###
        
        
    def forward(self, inputs):
        ### YOUR CODE BELOW ###
        embeds = self.embeddings(inputs)
        embeds = self.dropout(embeds)
        outputs, hidden = self.LSTM(embeds)
        #print(outputs.shape)
        #outputs = self.dropout(outputs)
        outputs = torch.max(outputs, dim = 1)[0]
        logits = self.projection(outputs)
        ### YOUR CODE ABOVE ###        
        
        return logits

# %%
# DATALOADER #
dataloader_train = torch.utils.data.DataLoader(dataset_train, shuffle=True, batch_size=64)
dataloader_test = torch.utils.data.DataLoader(dataset_test, shuffle=False, batch_size=64)

# MODEL INITIALIZATION #
model = TextClassificationModel(300, len(dataset_train.vocab), 128, 2, glove_matrix)#2 labels
if torch.cuda.is_available():
    model = model.cuda()
# OPTIMIZER #
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# LOSS-FUNCTION #
criterion = torch.nn.CrossEntropyLoss()

# %%
# TRAINING #
losses = []
for epoch in range(10):
    epoch_losses = []
    for i, batch in enumerate(dataloader_train):
        optimizer.zero_grad()
        
        x, y = batch
        if torch.cuda.is_available():
            x = x.cuda()
            y = y.cuda()
        
        #print(y)
        logits = model(x)
        loss = criterion(logits, y)
        
        epoch_losses.append(loss.item())
        
        loss.backward()
        optimizer.step()

    epoch_loss = np.mean(epoch_losses)
    losses.append(epoch_loss)
    print('Epoch {}, loss {}'.format(epoch, epoch_loss))
# Out:
# Epoch 0, loss 0.6945626664969881
# Epoch 1, loss 0.6878307704198159
# Epoch 2, loss 0.6771814237206669
# Epoch 3, loss 0.6622895153902345
# Epoch 4, loss 0.6324253102480355
# Epoch 5, loss 0.596064945398751
# Epoch 6, loss 0.5679370932659861
# Epoch 7, loss 0.5414608095662069
# Epoch 8, loss 0.5157701267024218
# Epoch 9, loss 0.495637558779474

# %%
import matplotlib.pyplot as plt
plt.plot(losses)
plt.ylabel("Training Loss")
plt.xlabel("Epoch")
plt.show()

# %%
def predict(model, dataloader):
    """
    Predict probability distributions over classes on the test data
    
    Args:
        model: your torch.nn.Module() model object
        dataloader: test Dataloder() object
        
    Returns:
        tuple: np.array/list with true labels and np.array/list with predicted labels
    """
    y_pred = []
    y_true = []
    
    ### YOUR CODE BELOW ###
    for i, batch in enumerate(dataloader):
        x, y = batch
        
        if torch.cuda.is_available():
            x = x.cuda()
            
        outputs = model(x).detach().cpu()
        y_pred.append(torch.argmax(outputs.data, 1))
        y_true.append(y)
        
    ### YOUR CODE ABOVE ###
        
    y_pred = np.concatenate(y_pred, axis=0)
    y_true = np.concatenate(y_true, axis=0)    
    
    return y_true, y_pred

# %%
y_true_train, y_pred_train = predict(model, dataloader_train)
y_true_test, y_pred_test = predict(model, dataloader_test)

# %%
### YOUR CODE BELOW ###
acc_train = accuracy_score(y_true_train, y_pred_train)
acc_test = accuracy_score(y_true_test, y_pred_test)
### YOUR CODE ABOVE ###

print('Accuracy train', acc_train)
print('Accuracy test', acc_test)
# Out:
# Accuracy train 0.7608230892570818
# Accuracy test 0.6432389096739711
